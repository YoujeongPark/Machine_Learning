# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
print(pd.__version__)
# Out:
# 0.25.3

# %%
df = pd.read_csv("https://www.data.go.kr/dataset/fileDownload.do?atchFileId=FILE_000000001578389&fileDetailSn=1&publicDataDetailPk=uddi:bdf05ab9-31ea-4d29-ac65-a64490fe425a_201909271615")
df.head(5)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-19-adc712e51ad3> in <module>
# ----> 1 df = pd.read_csv("https://www.data.go.kr/dataset/fileDownload.do?atchFileId=FILE_000000001578389&fileDetailSn=1&publicDataDetailPk=uddi:bdf05ab9-31ea-4d29-ac65-a64490fe425a_201909271615")
#       2 df.head(5)
#
# ...

# %%
df = pd.read_json("https://data.smcgov.org/resource/mb6a-xn89.json")
df.head(5)
# Out:
#         geography geography_type                     year  \
# 0        Atherton           Town  2014-01-01T00:00:00.000
# 1           Colma           Town  2014-01-01T00:00:00.000
# 2     Foster City           City  2014-01-01T00:00:00.000
# 3  Portola Valley           Town  2014-01-01T00:00:00.000
# 4    Redwood City           City  2014-01-01T00:00:00.000
#
#    less_than_high_school_graduate  high_school_graduate  \
# 0                            13.6                  12.3
# 1                             6.3                   6.4
# 2                            11.9                   9.7
# 3                            48.1                   0.0
# 4                            16.4                  10.6
#
#    some_college_or_associate_s_degree  bachelor_s_degree_or_higher  \
# 0                                 2.7                          3.5
# 1                                10.4                          2.4
# 2                                 2.0                          2.9
# ...

# %%
df.columns
# Out:
# Index(['geography', 'geography_type', 'year', 'less_than_high_school_graduate',
#        'high_school_graduate', 'some_college_or_associate_s_degree',
#        'bachelor_s_degree_or_higher', 'location_1',
#        ':@computed_region_uph5_8hpn', ':@computed_region_i2t2_cryp'],
#       dtype='object')

# %%
df['some_college_or_associate_s_degree'].plot()
plt.title('Accumulated Confirmed Count');

# %%
plt.figure(figsize=(10,6))
sns.set_style("darkgrid")
plt.title("Age distribution of the deceased")
sns.kdeplot(data=df['less_than_high_school_graduate'], shade=True)

# %%
plt.figure(figsize=(10,6))
sns.set_style("darkgrid")
plt.title("Age distribution of the deceased by gender")
sns.kdeplot(data=df['less_than_high_school_graduate'], shade=True)
sns.kdeplot(data=df['high_school_graduate'], shade=True)

# %%
plt.figure(figsize=(10,8))
sns.set_style("darkgrid")
sns.distplot(a=male_dead['age'], label="Men", kde=False)
sns.distplot(a=female_dead['age'], label="Women", kde=False)
plt.title("Age distribution of the deceased by sex")
plt.legend()
