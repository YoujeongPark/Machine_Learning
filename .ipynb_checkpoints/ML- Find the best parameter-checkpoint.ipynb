# %% [markdown]
# ## Find the best parameter
# 1. GridSearch
# 2. BayesianOptimization

# %%
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
from sklearn.model_selection import StratifiedKFold , train_test_split , KFold
# %matplotlib inline

# %%
iris = load_iris()
iris_label = iris.target 
iris_label = iris_label.reshape(len(iris_label),1)
iris_data = iris.data

# %%
total_iris_data = np.hstack([iris_data, iris_label])
irisDf = pd.DataFrame(data = total_iris_data, columns = ['sepal_length', 'sepal_width', 'petal_length','petal_width','label'])
irisDf.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  label
# 0           5.1          3.5           1.4          0.2    0.0
# 1           4.9          3.0           1.4          0.2    0.0
# 2           4.7          3.2           1.3          0.2    0.0

# %%
X_train, X_test, y_train, y_test = train_test_split(iris_data, iris_label, test_size = 0.2, random_state = 11)

# %% [markdown]
# ## 1. Grid Search

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
rfc=RandomForestClassifier(random_state=42)

# %%
param_grid = { 
    'n_estimators': [200, 500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [4,5,6,7,8],
    'criterion' :['gini', 'entropy']
}

# %%
CV_rfc = GridSearchCV(estimator=rfc, param_grid=param_grid, cv= 5)
CV_rfc.fit(X_train, y_train)
# Out:
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Aconda3\envs\test1\lib\site-packages\sklearn\model_selection\_search.py:715: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=RandomForestClassifier(bootstrap=True, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators='warn', n_jobs=None,
#                                               oob_score=False, random_state=42,
#                                               verbose=0, warm_start=False),
#              iid='warn', n_jobs=None,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [4, 5, 6, 7, 8],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [200, 500]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
CV_rfc.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 4,
#  'max_features': 'auto',
#  'n_estimators': 200}

# %%
CV_rfc.score(X_test, y_test)
# Out:
# 0.9333333333333333

# %% [markdown]
# ## 2. BayesianOptimization
# - https://github.com/fmfn/BayesianOptimization

# %%
import xgboost as xgb
from bayes_opt import BayesianOptimization
from sklearn.metrics import mean_squared_error

# %%
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test)

# %%
def xgb_evaluate(max_depth, gamma, colsample_bytree):
    params = {'eval_metric': 'rmse',
              'max_depth': int(max_depth),
              'subsample': 0.8,
              'eta': 0.1,
              'gamma': gamma,
              'colsample_bytree': colsample_bytree}
    # Used around 1000 boosting rounds in the full model
    cv_result = xgb.cv(params, dtrain, num_boost_round=100, nfold=3)    
    
    # Bayesian optimization only knows how to maximize, not minimize, so return the negative RMSE
    return -1.0 * cv_result['test-rmse-mean'].iloc[-1]

# %%
xgb_bo = BayesianOptimization(xgb_evaluate, {'max_depth': (3, 7), 
                                             'gamma': (0, 1),
                                             'colsample_bytree': (0.3, 0.9)})

# %%
# %%time
xgb_bo.maximize(init_points=10, n_iter=10)
# Out:
# |   iter    |  target   | colsam... |   gamma   | max_depth |
# -------------------------------------------------------------
# |  1        | -0.2626   |  0.4545   |  0.3145   |  4.561    |
# |  2        | -0.2643   |  0.4066   |  0.5222   |  5.02     |
# |  3        | -0.2801   |  0.3877   |  0.1135   |  5.54     |
# |  4        | -0.2188   |  0.5447   |  0.4376   |  4.533    |
# |  5        | -0.3082   |  0.3934   |  0.0108   |  4.212    |
# |  6        | -0.2225   |  0.6972   |  0.6869   |  5.31     |
# |  7        | -0.2235   |  0.6137   |  0.07268  |  4.697    |
# |  8        | -0.223    |  0.867    |  0.7894   |  5.302    |
# |  9        | -0.2678   |  0.3241   |  0.7919   |  4.154    |
# |  10       | -0.2203   |  0.5369   |  0.08622  |  6.587    |
# |  11       | -0.2287   |  0.9      |  1.0      |  3.0      |
# |  12       | -0.2713   |  0.3      |  1.0      |  7.0      |
# |  13       | -0.2229   |  0.9      |  0.0      |  3.0      |
# |  14       | -0.2199   |  0.9      |  0.0      |  7.0      |
# |  15       | -0.2119   |  0.9      |  0.4256   |  3.862    |
# |  16       | -0.2694   |  0.3      |  1.0      |  3.0      |
# |  17       | -0.3237   |  0.3      |  0.0      |  7.0      |
# |  18       | -0.2164   |  0.9      |  0.0      |  5.875    |
# |  19       | -0.2287   |  0.9      |  1.0      |  7.0      |
# |  20       | -0.2287   |  0.9      |  1.0      |  4.356    |
# =============================================================
# Wall time: 7.71 s

# %%
for i, res in enumerate(xgb_bo.res):
    print('Iteration {} : \n\t{}'.format(i,res))
# Out:
# Iteration 0 :
# 	{'target': -0.26264166666666666, 'params': {'colsample_bytree': 0.45445376797296744, 'gamma': 0.3145140514997339, 'max_depth': 4.56052683151028}}
# Iteration 1 :
# 	{'target': -0.264344, 'params': {'colsample_bytree': 0.406593559151036, 'gamma': 0.522232530675492, 'max_depth': 5.020008635159298}}
# Iteration 2 :
# 	{'target': -0.28006766666666666, 'params': {'colsample_bytree': 0.38765181415444794, 'gamma': 0.11352584219398687, 'max_depth': 5.540052843145371}}
# Iteration 3 :
# 	{'target': -0.21878366666666668, 'params': {'colsample_bytree': 0.5446958700195115, 'gamma': 0.4375899170036236, 'max_depth': 4.532729539211264}}
# Iteration 4 :
# 	{'target': -0.30824599999999996, 'params': {'colsample_bytree': 0.3934489731450411, 'gamma': 0.0108020215543696, 'max_depth': 4.211874543835191}}
# Iteration 5 :
# 	{'target': -0.22247633333333336, 'params': {'colsample_bytree': 0.6972398164775552, 'gamma': 0.6869310761440711, 'max_depth': 5.310151585830983}}
# Iteration 6 :
# 	{'target': -0.22346666666666667, 'params': {'colsample_bytree': 0.6137015765611227, 'gamma': 0.07268012640313148, 'max_depth': 4.697327896031297}}
# Iteration 7 :
# 	{'target': -0.22299733333333335, 'params': {'colsample_bytree': 0.8669772951581183, 'gamma': 0.7894331738393972, 'max_depth': 5.302254779821254}}
# Iteration 8 :
# 	{'target': -0.26783433333333334, 'params': {'colsample_bytree': 0.3241162166485993, 'gamma': 0.7919419379196365, 'max_depth': 4.153551652582297}}
# Iteration 9 :
# 	{'target': -0.22027566666666668, 'params': {'colsample_bytree': 0.5369373806218412, 'gamma': 0.08622375194994958, 'max_depth': 6.5865312776619085}}
# Iteration 10 :
# 	{'target': -0.22874966666666666, 'params': {'colsample_bytree': 0.9, 'gamma': 1.0, 'max_depth': 3.0}}
# Iteration 11 :
# 	{'target': -0.27127433333333334, 'params': {'colsample_bytree': 0.3, 'gamma': 1.0, 'max_depth': 7.0}}
# Iteration 12 :
# 	{'target': -0.22294433333333333, 'params': {'colsample_bytree': 0.9, 'gamma': 0.0, 'max_depth': 3.0}}
# Iteration 13 :
# 	{'target': -0.21989933333333334, 'params': {'colsample_bytree': 0.9, 'gamma': 0.0, 'max_depth': 7.0}}
# Iteration 14 :
# 	{'target': -0.21194533333333332, 'params': {'colsample_bytree': 0.9, 'gamma': 0.4255966405409401, 'max_depth': 3.862004501194054}}
# Iteration 15 :
# 	{'target': -0.269368, 'params': {'colsample_bytree': 0.3, 'gamma': 1.0, 'max_depth': 3.0}}
# Iteration 16 :
# 	{'target': -0.323724, 'params': {'colsample_bytree': 0.3, 'gamma': 0.0, 'max_depth': 7.0}}
# Iteration 17 :
# 	{'target': -0.21636333333333335, 'params': {'colsample_bytree': 0.9, 'gamma': 0.0, 'max_depth': 5.87540690248273}}
# Iteration 18 :
# 	{'target': -0.22874966666666666, 'params': {'colsample_bytree': 0.9, 'gamma': 1.0, 'max_depth': 7.0}}
# Iteration 19 :
# 	{'target': -0.22874966666666666, 'params': {'colsample_bytree': 0.9, 'gamma': 1.0, 'max_depth': 4.355889337321286}}

# %%
print("Final result : ", xgb_bo.max)
# Out:
# Final result :  {'target': -0.21194533333333332, 'params': {'colsample_bytree': 0.9, 'gamma': 0.4255966405409401, 'max_depth': 3.862004501194054}}

# %%
xgb2 = xgb.train(xgb_bo.max, dtrain , 100)
#lgb2 = lgb.train(params, d_train, 100)
xgb_prob = xgb2.predict( dtest )

# %%
from sklearn.metrics import mean_squared_error

opt_xgb_result = np.sqrt(mean_squared_error(y_test, xgb_prob))

# %%
from xgboost import plot_importance
xgb2 = xgb.train(xgb_bo.max, dtrain , 100)
#lgb2 = lgb.train(params, d_train, 100)
xgb_prob = xgb2.predict( dtest )

from sklearn.metrics import mean_squared_error

np.sqrt(mean_squared_error(y_test, xgb_prob))

import matplotlib.pyplot as plt
fix,ax = plt.subplots(figsize = (5,5))
plot_importance(xgb2, ax = ax)
plt.show()

# %% [markdown]
# # 3. Optuna
# - https://github.com/optuna/optuna
# - https://github.com/optuna/optuna/blob/master/examples/pruning/lightgbm_integration.py

# %%
import optuna
import sklearn

# %%
optuna.__version__
# Out:
# '1.1.0'

# %%
def objective(trial):
   
    n_estimators = trial.suggest_int('n_estimators', 2, 20)
    max_depth = int(trial.suggest_loguniform('max_depth', 1, 32))
    
    clf = sklearn.ensemble.RandomForestClassifier(
        n_estimators=n_estimators, max_depth=max_depth)
    
    return sklearn.model_selection.cross_val_score(
        clf, iris_data, iris_label, n_jobs=-1, cv=3).mean()

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

trial = study.best_trial
# Out:
# [I 2020-02-20 15:54:25,065] Finished trial#0 resulted in value: 0.9607843137254902. Current best value is 0.9607843137254902 with parameters: {'n_estimators': 3, 'max_depth': 7.1655225270183065}.
# [I 2020-02-20 15:54:26,317] Finished trial#1 resulted in value: 0.960375816993464. Current best value is 0.9607843137254902 with parameters: {'n_estimators': 3, 'max_depth': 7.1655225270183065}.
# [I 2020-02-20 15:54:27,502] Finished trial#2 resulted in value: 0.8623366013071895. Current best value is 0.9607843137254902 with parameters: {'n_estimators': 3, 'max_depth': 7.1655225270183065}.
# [I 2020-02-20 15:54:28,798] Finished trial#3 resulted in value: 0.9673202614379085. Current best value is 0.9673202614379085 with parameters: {'n_estimators': 17, 'max_depth': 7.569033206184819}.
# [I 2020-02-20 15:54:30,096] Finished trial#4 resulted in value: 0.7843137254901961. Current best value is 0.9673202614379085 with parameters: {'n_estimators': 17, 'max_depth': 7.569033206184819}.
# [I 2020-02-20 15:54:31,352] Finished trial#5 resulted in value: 0.9669117647058822. Current best value is 0.9673202614379085 with parameters: {'n_estimators': 17, 'max_depth': 7.569033206184819}.
# [I 2020-02-20 15:54:32,565] Finished trial#6 resulted in value: 0.9468954248366014. Current best value is 0.9673202614379085 with parameters: {'n_estimators': 17, 'max_depth': 7.569033206184819}.
# [I 2020-02-20 15:54:33,760] Finished trial#7 resulted in value: 0.7777777777777777. Current best value is 0.9673202614379085 with parameters: {'n_estimators': 17, 'max_depth': 7.569033206184819}.
# [I 2020-02-20 15:54:34,972] Finished trial#8 resulted in value: 0.9534313725490197. Current best value is 0.9673202614379085 with parameters: {'n_estimators': 17, 'max_depth': 7.569033206184819}.
# [I 2020-02-20 15:54:36,217] Finished trial#9 resulted in value: 0.9473039215686274. Current best value is 0.9673202614379085 with parameters: {'n_estimators': 17, 'max_depth': 7.569033206184819}.
# [I 2020-02-20 15:54:37,615] Finished trial#10 resulted in value: 0.9738562091503268. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:54:39,097] Finished trial#11 resulted in value: 0.960375816993464. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:54:40,485] Finished trial#12 resulted in value: 0.9534313725490197. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:54:41,702] Finished trial#13 resulted in value: 0.9599673202614379. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:54:42,961] Finished trial#14 resulted in value: 0.9468954248366014. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:54:44,237] Finished trial#15 resulted in value: 0.960375816993464. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:54:45,489] Finished trial#16 resulted in value: 0.9599673202614379. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:54:46,981] Finished trial#17 resulted in value: 0.9669117647058822. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:54:48,329] Finished trial#18 resulted in value: 0.9599673202614379. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:54:49,566] Finished trial#19 resulted in value: 0.9673202614379085. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:54:50,894] Finished trial#20 resulted in value: 0.9669117647058822. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:54:52,121] Finished trial#21 resulted in value: 0.9468954248366014. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:54:53,342] Finished trial#22 resulted in value: 0.960375816993464. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:54:54,627] Finished trial#23 resulted in value: 0.9534313725490197. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:54:55,944] Finished trial#24 resulted in value: 0.960375816993464. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:54:57,259] Finished trial#25 resulted in value: 0.9669117647058822. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:54:58,528] Finished trial#26 resulted in value: 0.9673202614379085. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:54:59,844] Finished trial#27 resulted in value: 0.960375816993464. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:01,271] Finished trial#28 resulted in value: 0.9599673202614379. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:02,779] Finished trial#29 resulted in value: 0.9669117647058822. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:04,191] Finished trial#30 resulted in value: 0.9738562091503268. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:05,647] Finished trial#31 resulted in value: 0.960375816993464. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:07,047] Finished trial#32 resulted in value: 0.9669117647058822. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:08,522] Finished trial#33 resulted in value: 0.9538398692810457. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:09,830] Finished trial#34 resulted in value: 0.9538398692810457. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:11,087] Finished trial#35 resulted in value: 0.960375816993464. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:12,512] Finished trial#36 resulted in value: 0.9607843137254902. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:13,854] Finished trial#37 resulted in value: 0.9468954248366014. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:15,180] Finished trial#38 resulted in value: 0.9673202614379085. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:16,426] Finished trial#39 resulted in value: 0.9673202614379085. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:17,683] Finished trial#40 resulted in value: 0.9607843137254902. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:19,052] Finished trial#41 resulted in value: 0.960375816993464. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:20,301] Finished trial#42 resulted in value: 0.9669117647058822. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:21,604] Finished trial#43 resulted in value: 0.9738562091503268. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:22,993] Finished trial#44 resulted in value: 0.9538398692810457. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:24,282] Finished trial#45 resulted in value: 0.9473039215686274. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:25,567] Finished trial#46 resulted in value: 0.9607843137254902. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:26,838] Finished trial#47 resulted in value: 0.9473039215686274. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:28,125] Finished trial#48 resulted in value: 0.9738562091503268. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:29,553] Finished trial#49 resulted in value: 0.9473039215686274. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:30,817] Finished trial#50 resulted in value: 0.9538398692810457. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:32,091] Finished trial#51 resulted in value: 0.960375816993464. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:33,458] Finished trial#52 resulted in value: 0.960375816993464. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:34,726] Finished trial#53 resulted in value: 0.7450980392156863. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:36,053] Finished trial#54 resulted in value: 0.9468954248366014. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:37,483] Finished trial#55 resulted in value: 0.960375816993464. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:38,789] Finished trial#56 resulted in value: 0.954248366013072. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:40,156] Finished trial#57 resulted in value: 0.9673202614379085. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:41,424] Finished trial#58 resulted in value: 0.9673202614379085. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:42,697] Finished trial#59 resulted in value: 0.960375816993464. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:44,071] Finished trial#60 resulted in value: 0.9673202614379085. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:45,486] Finished trial#61 resulted in value: 0.9468954248366014. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:46,783] Finished trial#62 resulted in value: 0.9607843137254902. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:48,305] Finished trial#63 resulted in value: 0.9534313725490197. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:49,665] Finished trial#64 resulted in value: 0.9669117647058822. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:50,942] Finished trial#65 resulted in value: 0.9673202614379085. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:52,220] Finished trial#66 resulted in value: 0.9673202614379085. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:53,605] Finished trial#67 resulted in value: 0.9538398692810457. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:55,002] Finished trial#68 resulted in value: 0.960375816993464. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:56,269] Finished trial#69 resulted in value: 0.9738562091503268. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:57,606] Finished trial#70 resulted in value: 0.9673202614379085. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:55:58,960] Finished trial#71 resulted in value: 0.9673202614379085. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:56:00,225] Finished trial#72 resulted in value: 0.954248366013072. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:56:01,506] Finished trial#73 resulted in value: 0.9599673202614379. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:56:02,802] Finished trial#74 resulted in value: 0.9607843137254902. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:56:04,195] Finished trial#75 resulted in value: 0.9534313725490197. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:56:05,675] Finished trial#76 resulted in value: 0.9534313725490197. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:56:07,005] Finished trial#77 resulted in value: 0.960375816993464. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:56:08,265] Finished trial#78 resulted in value: 0.9669117647058822. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:56:09,610] Finished trial#79 resulted in value: 0.9738562091503268. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:56:10,800] Finished trial#80 resulted in value: 0.9599673202614379. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:56:12,029] Finished trial#81 resulted in value: 0.9534313725490197. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:56:13,347] Finished trial#82 resulted in value: 0.960375816993464. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:56:14,557] Finished trial#83 resulted in value: 0.9665032679738562. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:56:15,806] Finished trial#84 resulted in value: 0.9538398692810457. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:56:17,045] Finished trial#85 resulted in value: 0.960375816993464. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:56:18,276] Finished trial#86 resulted in value: 0.960375816993464. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:56:19,619] Finished trial#87 resulted in value: 0.9673202614379085. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:56:20,854] Finished trial#88 resulted in value: 0.9538398692810457. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:56:22,131] Finished trial#89 resulted in value: 0.960375816993464. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:56:23,615] Finished trial#90 resulted in value: 0.9538398692810457. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:56:24,882] Finished trial#91 resulted in value: 0.9599673202614379. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:56:26,131] Finished trial#92 resulted in value: 0.9607843137254902. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:56:27,357] Finished trial#93 resulted in value: 0.960375816993464. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:56:28,671] Finished trial#94 resulted in value: 0.960375816993464. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:56:30,056] Finished trial#95 resulted in value: 0.9673202614379085. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:56:31,333] Finished trial#96 resulted in value: 0.9669117647058822. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:56:32,662] Finished trial#97 resulted in value: 0.9538398692810457. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:56:34,027] Finished trial#98 resulted in value: 0.9599673202614379. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# [I 2020-02-20 15:56:35,413] Finished trial#99 resulted in value: 0.9673202614379085. Current best value is 0.9738562091503268 with parameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}.
# Accuracy: 0.9738562091503268
# Best hyperparameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}

# %%
print('Accuracy: {}'.format(trial.value))
print("Best hyperparameters: {}".format(trial.params))
# Out:
# Accuracy: 0.9738562091503268
# Best hyperparameters: {'n_estimators': 19, 'max_depth': 27.236798483232246}

# %% [markdown]
# # 4. scikit-optimize
# - https://scikit-optimize.github.io/

# %% [markdown]
# # 5. Hyperopt
# - https://github.com/hyperopt/hyperopt-sklearn
# - https://github.com/hyperopt/hyperopt

# %% [markdown]
# # 7. Spearmint
# - https://github.com/JasperSnoek/spearmint

# %% [markdown]
# # 8. benderopt
# - https://github.com/Dreem-Organization/benderopt
